# %% [markdown]
# # Machine Learning Project GMIT by Greg Feeley
#
# ## Describe, Infer and Predict Using Boston Housing Dataset

# %%
#import libraries
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import seaborn as sns
import keras as kr
import sklearn.preprocessing as pre
import sklearn.model_selection as mod
import sklearn.decomposition as dec
# Out:
# Using TensorFlow backend.

# %%
#import dataset from sklearn and sklearn packages
from sklearn.datasets import load_boston
boston_dataset = load_boston()
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error

#assign dataframe and print sample edited from https://anujdutt9.github.io/LinearRegressionTF.html
df = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
print(df.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df['PRICE'] = boston_dataset.target
#show shape of data for inspection
df.shape
# Out:
# (506, 14)

# %%
#use pearson correlation method edited from https://pythontic.com/pandas/dataframe-computations/correlation
df.corr(method='pearson')
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# PRICE   -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT     PRICE
# CRIM    -0.379670  0.625505  0.582764  0.289946 -0.385064  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# PRICE    0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
#heatmap of correlation annotate each cell with numeric value 
sns.set(rc={'figure.figsize':(9.7,9.28)})
sns.heatmap(df.corr().round(4), square=True, annot=True)

# %%
#dataframe columns
df.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'PRICE'],
#       dtype='object')

# %%
#summary of data
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       PRICE
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# ### From the heatmap above we can see a correlation between the INDUS and NOX variable. We can use these variables for a regression model

# %%
#declare required varibale for regression and print
x_indus=df.INDUS
y_nox=df.NOX
print(x_indus)
print(y_nox)
# Out:
# 0       2.31
# 1       7.07
# 2       7.07
# 3       2.18
# 4       2.18
# 5       2.18
# 6       7.87
# 7       7.87
# 8       7.87
# 9       7.87
# 10      7.87
# 11      7.87
# 12      7.87
# 13      8.14
# 14      8.14
# 15      8.14
# 16      8.14
# 17      8.14
# 18      8.14
# 19      8.14
# 20      8.14
# 21      8.14
# 22      8.14
# 23      8.14
# 24      8.14
# 25      8.14
# 26      8.14
# 27      8.14
# 28      8.14
# 29      8.14
#        ...
# 476    18.10
# 477    18.10
# 478    18.10
# 479    18.10
# 480    18.10
# 481    18.10
# 482    18.10
# 483    18.10
# 484    18.10
# 485    18.10
# 486    18.10
# 487    18.10
# 488    27.74
# 489    27.74
# 490    27.74
# 491    27.74
# 492    27.74
# 493     9.69
# 494     9.69
# 495     9.69
# 496     9.69
# 497     9.69
# 498     9.69
# 499     9.69
# 500     9.69
# 501    11.93
# 502    11.93
# 503    11.93
# 504    11.93
# 505    11.93
# Name: INDUS, Length: 506, dtype: float64
# 0      0.538
# 1      0.469
# 2      0.469
# 3      0.458
# 4      0.458
# 5      0.458
# 6      0.524
# 7      0.524
# 8      0.524
# 9      0.524
# 10     0.524
# 11     0.524
# 12     0.524
# 13     0.538
# 14     0.538
# 15     0.538
# 16     0.538
# 17     0.538
# 18     0.538
# 19     0.538
# 20     0.538
# 21     0.538
# 22     0.538
# 23     0.538
# 24     0.538
# 25     0.538
# 26     0.538
# 27     0.538
# 28     0.538
# 29     0.538
#        ...
# 476    0.614
# 477    0.614
# 478    0.614
# 479    0.614
# 480    0.532
# 481    0.532
# 482    0.532
# 483    0.532
# 484    0.583
# 485    0.583
# 486    0.583
# 487    0.583
# 488    0.609
# 489    0.609
# 490    0.609
# 491    0.609
# 492    0.609
# 493    0.585
# 494    0.585
# 495    0.585
# 496    0.585
# 497    0.585
# 498    0.585
# 499    0.585
# 500    0.585
# 501    0.573
# 502    0.573
# 503    0.573
# 504    0.573
# 505    0.573
# Name: NOX, Length: 506, dtype: float64

# %%
#training and test variables with test size to define amount of dataset used
X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(x_indus, y_nox, test_size = 0.35)
#print shape of data used in sample
print(X_train_1.shape)
print(X_test_1.shape)
print(Y_train_1.shape)
print(Y_test_1.shape)
# Out:
# (328,)
# (178,)
# (328,)
# (178,)

# %%
#reshape the array without changing the data.
X_indus = np.array(x_indus).reshape(-1,1)
y_nox = np.array(y_nox).reshape(-1,1)

# %%
#split data edited from https://medium.com/@contactsunny/how-to-split-your-dataset-to-train-and-test-datasets-using-scikit-learn-e7cf6eb5e0d
X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(X_indus, y_nox, test_size = 0.2, random_state=0)

# %%
#start regression fit 
regression = LinearRegression()
regression.fit(X_train_1, Y_train_1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#prediction with non negative square root of array
y_train_predict_1 = regression.predict(X_train_1)
rmse = (np.sqrt(mean_squared_error(Y_train_1, y_train_predict_1)))
##print formatted version of rmse
print('RMSE is {}'.format(rmse))
# Out:
# RMSE is 0.07516631301681419

# %%
#evalute the test train set
prediction2 = regression.predict(X_test_1)
rmse = (np.sqrt(mean_squared_error(Y_test_1, prediction2)))
#round regression score to 3 decimals
root2 = round(regression.score(X_test_1, Y_test_1),3)
#print results
print("RMSE: {}".format(rmse))
print("R^2: {}".format(root2))
# Out:
# RMSE: 0.07337882835496352
# R^2: 0.616

# %%
##fit and predict model plot
##edited from https://campus.datacamp.com/courses/supervised-learning-with-scikit-learn/regression-2?ex=6
prediction_space = np.linspace(min(x_indus), max(x_indus)).reshape(-1,1) 
plt.scatter(x_indus,y_nox)
plt.plot(prediction_space, regression.predict(prediction_space), color = 'red', linewidth = 2)
plt.ylabel('proportion of owner-occupied units built prior to 1940')
plt.xlabel('nitric oxides concentration (parts per 10 million)')
plt.show()

# %%
#edited from https://scipy-lectures.org/packages/scikit-learn/auto_examples/plot_boston_prediction.html
#histogram of of column quantities in relation to price
plt.figure(figsize=(4, 3))
plt.hist(boston_dataset.target,color='purple' )
plt.xlabel('price ($1000s)')
plt.ylabel('count')
plt.tight_layout()
#show scatter for each column in relation to price use enumerate to loop
for index, feature_name in enumerate(boston_dataset.feature_names):
    plt.figure(figsize=(4, 3))
    plt.scatter(boston_dataset.data[:, index], boston_dataset.target,color='purple')
    plt.ylabel('Price', size=15)
    plt.xlabel(feature_name, size=15)
    plt.tight_layout()

# %% [markdown]
# When considering the Charles River(CHAS) data above we can infer from the scatter plot that whether a property positioned on the river has an effect on house price.*elaborate

# %% [markdown]
# ## Keras model

# %%
#prepare and print data for modelling
x = df[['CHAS', 'NOX', 'CRIM', 'RM','ZN', 'INDUS', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT
# 476    16.7
# 477    12.0
# 478    14.6
# 479    21.4
# 480    23.0
# 481    23.7
# 482    25.0
# 483    21.8
# 484    20.6
# 485    21.2
# 486    19.1
# 487    20.6
# 488    15.2
# 489     7.0
# 490     8.1
# 491    13.6
# 492    20.1
# 493    21.8
# 494    24.5
# 495    23.1
# 496    19.7
# 497    18.3
# 498    21.2
# 499    17.5
# 500    16.8
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %%
#split the dataset
x_train, x_test, y_train, y_test = mod.train_test_split(x, y, test_size=0.3)

# %%
#build the model
m = kr.models.Sequential()
#build model one hidden layer 15 neurons, 13 input neurons, single neuron in output layer.
m.add(kr.layers.Dense(15, input_dim=13, activation="relu"))
m.add(kr.layers.Dense(1, kernel_initializer="normal"))
#compile with MSE and adam optimiser.
m.compile(loss="mean_squared_error", optimizer="adam")
# Out:
# WARNING:tensorflow:From C:\Users\gregf\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
#fit model on training set with 100 epochs
m.fit(x_train, y_train, epochs=100, batch_size=10)
# Out:
# WARNING:tensorflow:From C:\Users\gregf\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 354/354 [==============================] - 0s 295us/step - loss: 483.4485
# Epoch 2/100
# 354/354 [==============================] - 0s 79us/step - loss: 96.4413
# Epoch 3/100
# 354/354 [==============================] - 0s 85us/step - loss: 76.9095
# Epoch 4/100
# 354/354 [==============================] - 0s 113us/step - loss: 69.4740
# Epoch 5/100
# 354/354 [==============================] - 0s 85us/step - loss: 66.9708
# Epoch 6/100
# 354/354 [==============================] - 0s 87us/step - loss: 66.3849
# Epoch 7/100
# 354/354 [==============================] - 0s 90us/step - loss: 62.9441
# Epoch 8/100
# 354/354 [==============================] - 0s 82us/step - loss: 62.5143
# Epoch 9/100
# 354/354 [==============================] - 0s 85us/step - loss: 61.4148
# Epoch 10/100
# 354/354 [==============================] - 0s 96us/step - loss: 63.0181
# Epoch 11/100
# 354/354 [==============================] - 0s 104us/step - loss: 60.9385
# Epoch 12/100
# 354/354 [==============================] - 0s 93us/step - loss: 60.0983
# Epoch 13/100
# 354/354 [==============================] - 0s 78us/step - loss: 58.7270
# Epoch 14/100
# 354/354 [==============================] - 0s 87us/step - loss: 58.8011
# Epoch 15/100
# 354/354 [==============================] - 0s 79us/step - loss: 56.6507
# Epoch 16/100
# 354/354 [==============================] - 0s 87us/step - loss: 56.6860
# Epoch 17/100
# 354/354 [==============================] - 0s 79us/step - loss: 55.9464
# Epoch 18/100
# 354/354 [==============================] - 0s 85us/step - loss: 56.2687
# Epoch 19/100
# 354/354 [==============================] - 0s 79us/step - loss: 55.0245
# Epoch 20/100
# 354/354 [==============================] - 0s 93us/step - loss: 56.3788
# Epoch 21/100
# 354/354 [==============================] - 0s 118us/step - loss: 53.8718
# Epoch 22/100
# 354/354 [==============================] - 0s 127us/step - loss: 56.0174
# Epoch 23/100
# 354/354 [==============================] - 0s 93us/step - loss: 54.6184
# Epoch 24/100
# 354/354 [==============================] - 0s 113us/step - loss: 52.5363
# Epoch 25/100
# Epoch 100/100
# 354/354 [==============================] - 0s 73us/step - loss: 36.6151

# %%
#prediction that network makes on set
m.predict(x_test).round().T
# Out:
# array([[24., 21., 20., 21., 21., 26., 23., 25., 24., 14., 26., 26., 23.,
#         28., 29., 24., 23., 15., 21., 21., 19., 27., 23., 21., 33., 29.,
#         19., 12., 26., 28., 18., 12., 31., 16., 27., 26., 19., 23., 16.,
#         31., 20., 21.,  5., 23., 15., 14., 19., 26., 23.,  8., 22.,  9.,
#         35., 26., 18., 26., 10., 14., 25., 24., 31., 25., 36., 34., 22.,
#         15., 25., 34., 23., 25., 27., 27., 32., 14., 29., 30., 23., 10.,
#         18., 21., 15., 29., 27., 30., 25., 34., 31., 12., 21., 22., 28.,
#         32., 19., 21., 25., 20., 22.,  8., 12., 30., 20., 22., 16., 32.,
#         23., 24., 15., 28., 24., 21., 22., 36., 11., 13., 13., 18., 30.,
#         13., 33., 36., 34., 19., 22., 31., 33., 22., 19., 25., 27., 32.,
#         18., 19., 28., 22., 19., 27., 23., 34., 26., 20., 25., 20., 25.,
#         34., 25., 22., 17., 23., 27., 32., 31., 23.]], dtype=float32)

# %%
#actual values from test set
y_test.as_matrix().astype(np.float32)
# Out:
# C:\Users\gregf\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# array([19.6, 21.4, 14.1, 16.4, 19.9, 23.3, 22.8, 23.2, 18.2,  8.1, 28.6,
#        22.8, 21.2, 25. , 21.6, 16. , 19.4, 10.2, 21.7, 15.6, 21.7, 42.8,
#        23.9, 17.5, 28.2, 33.1, 19.3,  8.7, 29. , 29.4, 17.4, 15.6, 24.5,
#        13.3, 37. , 26.4, 13. , 28.1, 12.8, 36.4, 17.5, 15. ,  5. , 22.2,
#        16.3, 17.2, 15. , 20.9, 21.7, 13.8, 20.4,  7.2, 33.4, 20.8, 11.5,
#        23.7, 10.2, 17.3, 18.9, 24.3, 32.7, 18.2, 50. , 43.1, 15.2, 20.4,
#        21.4, 50. , 19.6, 23.9, 22.9, 26.6, 50. , 13.4, 31.6, 30.1, 22. ,
#        14.4, 20. , 19.3, 15. , 28. , 25. , 24.4, 22.7, 36. , 35.1, 20.2,
#        18.7, 20.3, 19.4, 23.9, 15.4, 16.7, 23.4, 20. , 20.6,  8.8, 10.9,
#        31.1, 18.1, 17.6, 14.5, 34.9, 19.3, 24. , 19. , 25.1, 18.6, 18.9,
#        17.1, 31.6, 10.4, 11.7, 12. , 17. , 21.9, 11.8, 50. , 44. , 33.3,
#        19.5, 16.8, 31.5, 44.8, 19.4, 14.5, 19.2, 23.8, 23.6, 13.8, 17.8,
#        22.9, 19.9, 21.7, 20.5, 16.5, 41.7, 20.7, 12.6, 25. , 20.1, 18.5,
#        32.4, 23.1, 21.9, 18.3, 24.3, 18.9, 23.5, 31. , 22.6],
#       dtype=float32)

# %%
#use evaluate function to evaluate test set.
m.evaluate(x_test, y_test)
# Out:
# 152/152 [==============================] - 0s 164us/step
# 26.013464275159333
